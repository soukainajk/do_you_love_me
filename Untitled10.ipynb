# %% [markdown]
# <a href="https://colab.research.google.com/github/soukainajk/do_you_love_me-/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Main UI logic
import ipywidgets as widgets
from IPython.display import display, clear_output

output = widgets.Output()

question = widgets.Label("💬 Do you love me?")

button_yes = widgets.Button(description="Yes ❤️", button_style='success')
button_no = widgets.Button(description="No 💔", button_style='danger')
button_cancel = widgets.Button(description="Cancel 🤷", button_style='warning')

def on_yes_clicked(b):
    with output:
        clear_output()
        print("😊 I always knew you loved me.")

def on_no_clicked(b):
    with output:
        clear_output()
        print("😢 Please try again.")
        display_ui()

def on_cancel_clicked(b):
    with output:
        clear_output()
        print("❗ You must answer the question.")
        display_ui()

def display_ui():
    display(question, widgets.HBox([button_yes, button_no, button_cancel]))

# Connect buttons to actions
button_yes.on_click(on_yes_clicked)
button_no.on_click(on_no_clicked)
button_cancel.on_click(on_cancel_clicked)

# Display UI
display_ui()
display(output)
# Out:
# Label(value='💬 Do you love me?')
# HBox(children=(Button(button_style='success', description='Yes ❤️', style=ButtonStyle()), Button(button_style=…
# Output()
